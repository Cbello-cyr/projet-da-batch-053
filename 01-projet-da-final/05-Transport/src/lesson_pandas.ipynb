# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
# We can create a DataFrame manually
df = pd.DataFrame({"name": ["Einstein", "Turing", "Nash"],
 "birth_year": [1879, 1912, 1928]})

df
# Out:
#        name  birth_year
# 0  Einstein        1879
# 1    Turing        1912
# 2      Nash        1928

# %%
#importer un fichier


df = pd.read_csv('imdb_1000.csv')
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
df.tail()
# Out:
#      star_rating                                            title  \
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
df.describe(include='object')
# Out:
#           title content_rating  genre  \
# count       979            976    979
# unique      975             12     16
# top     Dracula              R  Drama
# freq          2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
df.describe(include='all')
# Out:
#         star_rating    title content_rating  genre    duration  \
# count    979.000000      979            976    979  979.000000
# unique          NaN      975             12     16         NaN
# top             NaN  Dracula              R  Drama         NaN
# freq            NaN        2            460    278         NaN
# mean       7.889785      NaN            NaN    NaN  120.979571
# std        0.336069      NaN            NaN    NaN   26.218010
# min        7.400000      NaN            NaN    NaN   64.000000
# 25%        7.600000      NaN            NaN    NaN  102.000000
# 50%        7.800000      NaN            NaN    NaN  117.000000
# 75%        8.100000      NaN            NaN    NaN  134.000000
# max        9.300000      NaN            NaN    NaN  242.000000
#
#                                               actors_list
# count                                                 979
# unique                                                969
# ...

# %%
#changer l'index
df = df.set_index('title')

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['title'], inplace=True)

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
df.columns
# Out:
# Index(['star_rating', 'content_rating', 'genre', 'duration', 'actors_list'], dtype='object')

# %%
df.index
# Out:
# Index(['The Shawshank Redemption', 'The Godfather', 'The Godfather: Part II',
#        'The Dark Knight', 'Pulp Fiction', '12 Angry Men',
#        'The Good, the Bad and the Ugly',
#        'The Lord of the Rings: The Return of the King', 'Schindler's List',
#        'Fight Club',
#        ...
#        'Law Abiding Citizen', 'Wonder Boys', 'Death at a Funeral',
#        'Blue Valentine', 'The Cider House Rules', 'Tootsie',
#        'Back to the Future Part III',
#        'Master and Commander: The Far Side of the World', 'Poltergeist',
#        'Wall Street'],
#       dtype='object', name='title', length=979)

# %%
df['genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df[['genre', 'star_rating']].value_counts().head(50)
# Out:
# genre      star_rating
# Drama      8.1            36
#            7.5            34
#            8.0            32
#            7.6            30
#            7.7            29
#            7.8            28
# Comedy     7.7            25
# Action     7.6            25
# Comedy     7.6            23
# Action     7.8            21
# Drama      7.9            21
# Comedy     7.8            20
# Crime      7.5            20
# Action     7.7            18
# Drama      8.2            16
# Comedy     7.4            15
# Crime      8.1            15
#            7.7            15
# Comedy     7.5            14
#            8.1            14
# Crime      7.6            13
# Drama      8.3            12
# Biography  7.6            12
# Drama      7.4            12
# Crime      7.8            12
# Adventure  8.0            12
# Comedy     8.0            12
# Action     8.1            12
# Biography  7.8            11
# Action     7.9            11
# Drama      8.4            11
# ...

# %%
#Option pandas afficher plus de lignes

pd.set_option('display.max_rows', 500)

# %%
df[['genre', 'star_rating']].value_counts()
# Out:
# genre      star_rating
# Drama      8.1            36
#            7.5            34
#            8.0            32
#            7.6            30
#            7.7            29
#            7.8            28
# Comedy     7.7            25
# Action     7.6            25
# Comedy     7.6            23
# Action     7.8            21
# Drama      7.9            21
# Comedy     7.8            20
# Crime      7.5            20
# Action     7.7            18
# Drama      8.2            16
# Comedy     7.4            15
# Crime      8.1            15
#            7.7            15
# Comedy     7.5            14
#            8.1            14
# Crime      7.6            13
# Drama      8.3            12
# Biography  7.6            12
# Drama      7.4            12
# Crime      7.8            12
# Adventure  8.0            12
# Comedy     8.0            12
# Action     8.1            12
# Biography  7.8            11
# Action     7.9            11
# Drama      8.4            11
# ...

# %%
#describe


df.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df['star_rating'].mean()
# Out:
# 7.889785495403474

# %%
df['star_rating'].median()
# Out:
# 7.8

# %%
df['star_rating'].min(), df['star_rating'].max()
# Out:
# (7.4, 9.3)

# %%
df['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df['genre'].nunique() #numbers
# Out:
# 16

# %%
count_values = df['genre'].value_counts()
count_values
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
type(count_values)
# Out:
# pandas.core.series.Series

# %%
count_values.index
# Out:
# Index(['Drama', 'Comedy', 'Action', 'Crime', 'Biography', 'Adventure',
#        'Animation', 'Horror', 'Mystery', 'Western', 'Sci-Fi', 'Thriller',
#        'Film-Noir', 'Family', 'History', 'Fantasy'],
#       dtype='object')

# %%
count_values.values
# Out:
# array([278, 156, 136, 124,  77,  75,  62,  29,  16,   9,   5,   5,   3,
#          2,   1,   1])

# %%
type(df['star_rating'])
# Out:
# pandas.core.series.Series

# %%
type(df['star_rating'].values)
# Out:
# numpy.ndarray

# %% [markdown]
# #  datas selections

# %%
# Iloc pour index

# %%
df.iloc[:,2]
# Out:
# title
# The Shawshank Redemption                               Crime
# The Godfather                                          Crime
# The Godfather: Part II                                 Crime
# The Dark Knight                                       Action
# Pulp Fiction                                           Crime
#                                                      ...
# Tootsie                                               Comedy
# Back to the Future Part III                        Adventure
# Master and Commander: The Far Side of the World       Action
# Poltergeist                                           Horror
# Wall Street                                            Crime
# Name: genre, Length: 979, dtype: object

# %%
df.iloc[20] #ligne 21
# Out:
# star_rating                                                     8.7
# content_rating                                                    R
# genre                                                        Action
# duration                                                        136
# actors_list       [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# Name: The Matrix, dtype: object

# %%
df.iloc[:, [2, 0, 3]]
# Out:
#                                                      genre  star_rating  \
# title
# The Shawshank Redemption                             Crime          9.3
# The Godfather                                        Crime          9.2
# The Godfather: Part II                               Crime          9.1
# The Dark Knight                                     Action          9.0
# Pulp Fiction                                         Crime          8.9
# ...                                                    ...          ...
# Tootsie                                             Comedy          7.4
# Back to the Future Part III                      Adventure          7.4
# Master and Commander: The Far Side of the World     Action          7.4
# Poltergeist                                         Horror          7.4
# Wall Street                                          Crime          7.4
#
#                                                  duration
# title
# ...

# %%
df.iloc[:, ['genre']]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [84], line 1
# ----> 1 df.iloc[:, ['genre']]
#
# File ~/.pyenv/versions/Artefact/lib/python3.10/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/.pyenv/versions/Artefact/lib/python3.10/site-packages/pandas/core/indexing.py:1461, in _iLocIndexer._getitem_tuple(self, tup)
#    1459 def _getitem_tuple(self, tup: tuple):
# -> 1461     tup = self._validate_tuple_indexer(tup)
#    1462     with suppress(IndexingError):
#    1463         return self._getitem_lowerdim(tup)
#
# ...

# %%
# .loc pour les clés

# %%
df.loc['Inception', 'genre']
# Out:
# 'Action'

# %%
df.loc[:, 'genre']
# Out:
# title
# The Shawshank Redemption                               Crime
# The Godfather                                          Crime
# The Godfather: Part II                                 Crime
# The Dark Knight                                       Action
# Pulp Fiction                                           Crime
#                                                      ...
# Tootsie                                               Comedy
# Back to the Future Part III                        Adventure
# Master and Commander: The Far Side of the World       Action
# Poltergeist                                           Horror
# Wall Street                                            Crime
# Name: genre, Length: 979, dtype: object

# %% [markdown]
# ### si on veut juste afficher une ou plusieur colonnes par besoin de loc ou de iloc

# %%
df['genre']
# Out:
# title
# The Shawshank Redemption                               Crime
# The Godfather                                          Crime
# The Godfather: Part II                                 Crime
# The Dark Knight                                       Action
# Pulp Fiction                                           Crime
#                                                      ...
# Tootsie                                               Comedy
# Back to the Future Part III                        Adventure
# Master and Commander: The Far Side of the World       Action
# Poltergeist                                           Horror
# Wall Street                                            Crime
# Name: genre, Length: 979, dtype: object

# %%
# Combiner les deux

df.iloc[:10]['genre']
# Out:
# title
# The Shawshank Redemption                             Crime
# The Godfather                                        Crime
# The Godfather: Part II                               Crime
# The Dark Knight                                     Action
# Pulp Fiction                                         Crime
# 12 Angry Men                                         Drama
# The Good, the Bad and the Ugly                     Western
# The Lord of the Rings: The Return of the King    Adventure
# Schindler's List                                 Biography
# Fight Club                                           Drama
# Name: genre, dtype: object

# %% [markdown]
# # Filtres (!!!)

# %%
df['genre'] == 'Drama'
# Out:
# title
# The Shawshank Redemption                           False
# The Godfather                                      False
# The Godfather: Part II                             False
# The Dark Knight                                    False
# Pulp Fiction                                       False
#                                                    ...
# Tootsie                                            False
# Back to the Future Part III                        False
# Master and Commander: The Far Side of the World    False
# Poltergeist                                        False
# Wall Street                                        False
# Name: genre, Length: 979, dtype: bool

# %%
df[df['genre'] == 'Drama'] #tous en une ligne
# Out:
#                                  star_rating content_rating  genre  duration  \
# title
# 12 Angry Men                             8.9      NOT RATED  Drama        96
# Fight Club                               8.9              R  Drama       139
# Forrest Gump                             8.8          PG-13  Drama       142
# One Flew Over the Cuckoo's Nest          8.7              R  Drama       133
# Seven Samurai                            8.7        UNRATED  Drama       207
# ...                                      ...            ...    ...       ...
# My Sister's Keeper                       7.4          PG-13  Drama       109
# The English Patient                      7.4              R  Drama       162
# Wonder Boys                              7.4              R  Drama       107
# Blue Valentine                           7.4          NC-17  Drama       112
# The Cider House Rules                    7.4          PG-13  Drama       126
#
# ...

# %%
pd.set_option('display.max_rows', 20)

# %%
and -> &
or -> |

# %%
df[(df['genre'] == 'Drama') & (df['duration'] > 120)]
# Out:
#                                  star_rating content_rating  genre  duration  \
# title
# Fight Club                               8.9              R  Drama       139
# Forrest Gump                             8.8          PG-13  Drama       142
# One Flew Over the Cuckoo's Nest          8.7              R  Drama       133
# Seven Samurai                            8.7        UNRATED  Drama       207
# It's a Wonderful Life                    8.7       APPROVED  Drama       130
# ...                                      ...            ...    ...       ...
# Across the Universe                      7.5          PG-13  Drama       133
# A Bridge Too Far                         7.4             PG  Drama       175
# Zero Dark Thirty                         7.4              R  Drama       157
# The English Patient                      7.4              R  Drama       162
# The Cider House Rules                    7.4          PG-13  Drama       126
#
# ...

# %%
df[(df['genre'] == 'Drama') & (df['duration'] > 120) | (df['genre'] == 'Fantasy')]
# Out:
#                                  star_rating content_rating  genre  duration  \
# title
# Fight Club                               8.9              R  Drama       139
# Forrest Gump                             8.8          PG-13  Drama       142
# One Flew Over the Cuckoo's Nest          8.7              R  Drama       133
# Seven Samurai                            8.7        UNRATED  Drama       207
# It's a Wonderful Life                    8.7       APPROVED  Drama       130
# ...                                      ...            ...    ...       ...
# Across the Universe                      7.5          PG-13  Drama       133
# A Bridge Too Far                         7.4             PG  Drama       175
# Zero Dark Thirty                         7.4              R  Drama       157
# The English Patient                      7.4              R  Drama       162
# The Cider House Rules                    7.4          PG-13  Drama       126
#
# ...

# %%
#tilde ~  -> negation
df[(df['genre'] != 'Drama')]
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
#tilde ~  -> negation
df[~(df['genre'] == 'Drama')]
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %% [markdown]
# ## Group By

# %%
df.groupby('genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].mean().sort_values()
# Out:
# genre
# History       66.000000
# Animation     96.596774
# Film-Noir     97.333333
# Horror       102.517241
# Family       107.500000
# Comedy       107.602564
# Sci-Fi       109.000000
# Fantasy      112.000000
# Thriller     114.200000
# Mystery      115.625000
# Crime        122.298387
# Action       126.485294
# Drama        126.539568
# Biography    131.844156
# Adventure    134.840000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df.groupby('genre')['duration'].mean().sort_values(ascending=False)
# Out:
# genre
# Western      136.666667
# Adventure    134.840000
# Biography    131.844156
# Drama        126.539568
# Action       126.485294
# Crime        122.298387
# Mystery      115.625000
# Thriller     114.200000
# Fantasy      112.000000
# Sci-Fi       109.000000
# Comedy       107.602564
# Family       107.500000
# Horror       102.517241
# Film-Noir     97.333333
# Animation     96.596774
# History       66.000000
# Name: duration, dtype: float64

# %%
df[['genre', 'duration']]
# Out:
#                                                      genre  duration
# title
# The Shawshank Redemption                             Crime       142
# The Godfather                                        Crime       175
# The Godfather: Part II                               Crime       200
# The Dark Knight                                     Action       152
# Pulp Fiction                                         Crime       154
# ...                                                    ...       ...
# Tootsie                                             Comedy       116
# Back to the Future Part III                      Adventure       118
# Master and Commander: The Far Side of the World     Action       138
# Poltergeist                                         Horror       114
# Wall Street                                          Crime       126
#
# [979 rows x 2 columns]

# %%
resume = df.groupby('genre')[['duration', 'star_rating']].mean().sort_values(by='duration',ascending=False)

# %%
resume[resume['star_rating'] > 8]
# Out:
#              duration  star_rating
# genre
# Western    136.666667     8.255556
# Film-Noir   97.333333     8.033333

# %%
#méthode sur une ligne

# %%
df.groupby('genre')[['duration', 'star_rating']].mean().sort_values(by='duration',ascending=False)[df.groupby('genre')[['duration', 'star_rating']].mean().sort_values(by='duration',ascending=False)['duration'] > 8]
# Out:
#              duration  star_rating
# genre
# Western    136.666667     8.255556
# Adventure  134.840000     7.933333
# Biography  131.844156     7.862338
# Drama      126.539568     7.902518
# Action     126.485294     7.884559
# Crime      122.298387     7.916935
# Mystery    115.625000     7.975000
# Thriller   114.200000     7.680000
# Fantasy    112.000000     7.700000
# Sci-Fi     109.000000     7.920000
# Comedy     107.602564     7.822436
# Family     107.500000     7.850000
# Horror     102.517241     7.806897
# Film-Noir   97.333333     8.033333
# Animation   96.596774     7.914516
# History     66.000000     8.000000

# %% [markdown]
# # Créer des colonnes

# %%
df['new_col'] = 'coucou'

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
df['2_star_rating'] = df['star_rating'] * 2

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
df['3_star_rating'] = df['star_rating'].apply(lambda x: x * 3)

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
eval("['toto', 'titi']")
# Out:
# ['toto', 'titi']

# %%
eval('3 + 6')
# Out:
# 9

# %%
eval('')

# %%
df['main_actor'] = df['actors_list'].apply(lambda x: eval(x)[0])

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
def lenght_movie (toto):
    if toto > 120:
        return 'long_movie'
    else:
        return 'short_movie'

# %%
df['lenght_movie'] = df['duration'].apply(lambda x : lenght_movie(x))

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
df['lenght_movie'] = df['duration'].apply(lenght_movie)

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
# supprimer une colonne

df.drop('new_col', axis=1, inplace=True)

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                 9.3              R
# The Godfather                                            9.2              R
# The Godfather: Part II                                   9.1              R
# The Dark Knight                                          9.0          PG-13
# Pulp Fiction                                             8.9              R
# ...                                                      ...            ...
# Tootsie                                                  7.4             PG
# Back to the Future Part III                              7.4             PG
# Master and Commander: The Far Side of the World          7.4          PG-13
# Poltergeist                                              7.4             PG
# Wall Street                                              7.4              R
#
# ...

# %%
#null value

# %%
data = pd.read_csv('class-grades.csv')
data
# Out:
#     Prefix  Assignment  Tutorial  Midterm TakeHome  Final
# 0        5       57.14     34.09    64.38    51.48   52.5
# 1        8       95.05    105.49    67.50    99.07  68.33
# 2        8       83.70     83.17    30.00    63.15  48.89
# 3        7       81.22     96.06    49.38   105.93  80.56
# 4        8       91.32     93.64    95.00   107.41  73.89
# ..     ...         ...       ...      ...      ...    ...
# 94       8       96.73    103.71    45.00    93.52  61.94
# 95       7       85.34     80.54    41.25     93.7  39.72
# 96       8       89.94    102.77    87.50    90.74  87.78
# 97       7       95.60     76.13    66.25    99.81  85.56
# 98       8       63.40     97.37    73.12    72.78  77.22
#
# [99 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  99 non-null     float64
#  2   Tutorial    99 non-null     float64
#  3   Midterm     99 non-null     float64
#  4   TakeHome    99 non-null     object
#  5   Final       99 non-null     object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
data = pd.read_csv('class-grades.csv', na_values='?')
data
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [99 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Prefix      99 non-null     int64
#  1   Assignment  99 non-null     float64
#  2   Tutorial    99 non-null     float64
#  3   Midterm     99 non-null     float64
#  4   TakeHome    98 non-null     float64
#  5   Final       96 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
data.fillna('coucou') #replace null value

# %%
data.dropna(inplace=True) #toute les lignes avec des valeurs null
# Out:
#     Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0        5       57.14     34.09    64.38     51.48  52.50
# 1        8       95.05    105.49    67.50     99.07  68.33
# 2        8       83.70     83.17    30.00     63.15  48.89
# 3        7       81.22     96.06    49.38    105.93  80.56
# 4        8       91.32     93.64    95.00    107.41  73.89
# ..     ...         ...       ...      ...       ...    ...
# 94       8       96.73    103.71    45.00     93.52  61.94
# 95       7       85.34     80.54    41.25     93.70  39.72
# 96       8       89.94    102.77    87.50     90.74  87.78
# 97       7       95.60     76.13    66.25     99.81  85.56
# 98       8       63.40     97.37    73.12     72.78  77.22
#
# [95 rows x 6 columns]

# %%
## convetir une colonne

# %%
data['Final'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In [162], line 1
# ----> 1 data['Final'].astype(int)
#
# File ~/.pyenv/versions/Artefact/lib/python3.10/site-packages/pandas/core/generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~/.pyenv/versions/Artefact/lib/python3.10/site-packages/pandas/core/internals/managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df['star_rating'] = df['star_rating'].astype(int)

# %%
df
# Out:
#                                                  star_rating content_rating  \
# title
# The Shawshank Redemption                                   9              R
# The Godfather                                              9              R
# The Godfather: Part II                                     9              R
# The Dark Knight                                            9          PG-13
# Pulp Fiction                                               8              R
# ...                                                      ...            ...
# Tootsie                                                    7             PG
# Back to the Future Part III                                7             PG
# Master and Commander: The Far Side of the World            7          PG-13
# Poltergeist                                                7             PG
# Wall Street                                                7              R
#
# ...

# %%
# Let's create two series
s1 = pd.Series(['apple', 'orange', 'banana'],
               index=[1, 2, 4])
s2 = pd.Series(['pineapple', 'wildberry', 'raspberry'],
               index=[3, 2, 6])

print(s1)
print('---------------')
print('---------------')
print(s2)
# Out:
# 1     apple
# 2    orange
# 4    banana
# dtype: object
# ---------------
# ---------------
# 3    pineapple
# 2    wildberry
# 6    raspberry
# dtype: object

# %%
pd.concat([s1, s2], axis=0)
# Out:
# 1        apple
# 2       orange
# 4       banana
# 3    pineapple
# 2    wildberry
# 6    raspberry
# dtype: object

# %%
pd.concat([s1, s2], axis=1)
# Out:
#         0          1
# 1   apple        NaN
# 2  orange  wildberry
# 4  banana        NaN
# 3     NaN  pineapple
# 6     NaN  raspberry

# %%
#merge == Jointure


# Let's create two new dataframes
meal = ['pizza', 'pasta', 'burger']
prices = [11.8, 12.9, 15.60]
calories = [870, 790, 950]

prices = pd.DataFrame({'meal': meal, 'price': prices})
calories = pd.DataFrame({'meal': meal, 'calories': calories})

# %%
prices
# Out:
#      meal  price
# 0   pizza   11.8
# 1   pasta   12.9
# 2  burger   15.6

# %%
calories
# Out:
#      meal  calories
# 0   pizza       870
# 1   pasta       790
# 2  burger       950

# %%
prices.merge(calories)
# Out:
#      meal  price  calories
# 0   pizza   11.8       870
# 1   pasta   12.9       790
# 2  burger   15.6       950

# %%
prices.merge(calories, how='inner', left_on='meal', right_on='meal')
# Out:
#      meal  price  calories
# 0   pizza   11.8       870
# 1   pasta   12.9       790
# 2  burger   15.6       950

# %%
# Let's create two new dataframes
meal = ['pizza', 'pasta', 'burger']
prices = [11.8, 12.9, 15.60]
calories = [870, 790, 950]

prices = pd.DataFrame({'meal': meal, 'price': prices})
calories = pd.DataFrame({'food': meal, 'calories': calories})

# %%
prices
# Out:
#      meal  price
# 0   pizza   11.8
# 1   pasta   12.9
# 2  burger   15.6

# %%
calories
# Out:
#      food  calories
# 0   pizza       870
# 1   pasta       790
# 2  burger       950

# %%
joined = prices.merge(calories, how='inner', left_on='meal', right_on='food')
joined
# Out:
#      meal  price    food  calories
# 0   pizza   11.8   pizza       870
# 1   pasta   12.9   pasta       790
# 2  burger   15.6  burger       950

# %% [markdown]
# # Save the DataFrame

# %%
joined.to_csv('joined.csv')
